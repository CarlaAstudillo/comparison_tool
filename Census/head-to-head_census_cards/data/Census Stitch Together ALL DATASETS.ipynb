# %%
import pandas as pd

# %%
#Add all datasets
#median income is already in census data towns
median_income = pd.read_csv("census_data_towns.csv")
population = pd.read_csv("population_data_towns.csv")
age = pd.read_csv("median-age.csv")
race = pd.read_csv("race-w-hisp.csv")
poverty = pd.read_csv("poverty.csv")
home_values = pd.read_csv("housingvalues_v2.csv")
home_costs = pd.read_csv("housingcosts.csv")
commute = pd.read_csv("commutetimes.csv")

# %%
len(population.index)
# Out:
# 586

# %%
len(median_income.index)
# Out:
# 586

# %%
merge1 = pd.merge(median_income, population, left_on='GEO.id2', right_on='GEO.id2', how='left')

# %%
len(merge1.index)
# Out:
# 586

# %%
merge1.head(5)
# Out:
#       GEOdisplaylabel_x    County_x             GEO.id_x     GEO.id2  \
# 0          Absecon city   Atlantic   0600000US3400100100  3400100100
# 1    Atlantic City city   Atlantic   0600000US3400102080  3400102080
# 2       Brigantine city   Atlantic   0600000US3400107810  3400107810
# 3         Buena borough   Atlantic   0600000US3400108680  3400108680
# 4  Buena Vista township   Atlantic   0600000US3400108710  3400108710
#
#                   GEOdisplaylabel_long_x median_income_latest  \
# 0          Absecon city, Atlantic County                63656
# 1    Atlantic City city, Atlantic County                25737
# 2       Brigantine city, Atlantic County                57031
# 3         Buena borough, Atlantic County                46169
# 4  Buena Vista township, Atlantic County                50421
#
#    median_income_latest_moe  median_income_prev_woinf  \
# 0                      9225                     69782
# 1                      1450                     30601
# ...

# %%
merge1 = merge1.drop(['GEOdisplaylabel_y', 'County_y', 'GEO.id_y', 'GEOdisplaylabel_long_y'], axis=1)
merge1.rename(columns={'GEOdisplaylabel_x': 'GEOdisplaylabel', 'County_x': 'County', 'GEO.id_x': 'GEO.id', 'GEOdisplaylabel_long_x': 'GEOdisplaylabel_long'}, inplace=True)

# %%
list(merge1)
# Out:
# ['GEOdisplaylabel',
#  'County',
#  'GEO.id',
#  'GEO.id2',
#  'GEOdisplaylabel_long',
#  'median_income_latest',
#  'median_income_latest_moe',
#  'median_income_prev_woinf',
#  'median_income_prev_moe_inf',
#  'median_income_prev',
#  'median_income_moe_prev',
#  'median_income_moe_latest_per',
#  'median_income_moe_prev_per',
#  'nj_median_income_latest',
#  'nj_median_income_prev',
#  'usa_median_income_latest',
#  'usa_median_income_prev',
#  'median_income_change',
#  'nj_median_income_change',
#  'usa_median_income_change',
#  'population_latest',
#  'population_latest_moe',
#  'population_prev',
#  'population_prev_moe',
#  'population_moe_latest_per',
#  'population_moe_prev_per',
#  'nj_population_latest',
#  'nj_population_prev',
#  'usa_population_latest',
#  'usa_population_prev',
#  'population_change',
#  'nj_population_change',
#  'usa_population_change']

# %%
merge2 = pd.merge(merge1, age, left_on='GEO.id2', right_on='Id2', how='left')

# %%
len(merge2.index)
# Out:
# 586

# %%
list(merge2)
# Out:
# ['GEOdisplaylabel',
#  'County_x',
#  'GEO.id',
#  'GEO.id2',
#  'GEOdisplaylabel_long',
#  'median_income_latest',
#  'median_income_latest_moe',
#  'median_income_prev_woinf',
#  'median_income_prev_moe_inf',
#  'median_income_prev',
#  'median_income_moe_prev',
#  'median_income_moe_latest_per',
#  'median_income_moe_prev_per',
#  'nj_median_income_latest',
#  'nj_median_income_prev',
#  'usa_median_income_latest',
#  'usa_median_income_prev',
#  'median_income_change',
#  'nj_median_income_change',
#  'usa_median_income_change',
#  'population_latest',
#  'population_latest_moe',
#  'population_prev',
#  'population_prev_moe',
#  'population_moe_latest_per',
#  'population_moe_prev_per',
#  'nj_population_latest',
#  'nj_population_prev',
#  'usa_population_latest',
#  'usa_population_prev',
#  'population_change',
#  'nj_population_change',
#  'usa_population_change',
#  'Id2',
#  'ledgerstyle',
#  'County_y',
#  'median_age_latest',
#  'median_age_moe_latest',
# ...

# %%
merge2 = merge2.drop(['Id2', 'County_y'], axis=1)
merge2.rename(columns={'County_x': 'County'}, inplace=True)

# %%
len(merge2.index)
# Out:
# 586

# %%
merge2.head(5)
# Out:
#         GEOdisplaylabel      County               GEO.id     GEO.id2  \
# 0          Absecon city   Atlantic   0600000US3400100100  3400100100
# 1    Atlantic City city   Atlantic   0600000US3400102080  3400102080
# 2       Brigantine city   Atlantic   0600000US3400107810  3400107810
# 3         Buena borough   Atlantic   0600000US3400108680  3400108680
# 4  Buena Vista township   Atlantic   0600000US3400108710  3400108710
#
#                     GEOdisplaylabel_long median_income_latest  \
# 0          Absecon city, Atlantic County                63656
# 1    Atlantic City city, Atlantic County                25737
# 2       Brigantine city, Atlantic County                57031
# 3         Buena borough, Atlantic County                46169
# 4  Buena Vista township, Atlantic County                50421
#
#    median_income_latest_moe  median_income_prev_woinf  \
# 0                      9225                     69782
# 1                      1450                     30601
# ...

# %%
merge3 = pd.merge(merge2, race, left_on='GEO.id2', right_on='Id2', how='left')

# %%
len(merge3.index)
# Out:
# 586

# %%
list(merge3)
# Out:
# ['GEOdisplaylabel',
#  'County_x',
#  'GEO.id',
#  'GEO.id2',
#  'GEOdisplaylabel_long',
#  'median_income_latest',
#  'median_income_latest_moe',
#  'median_income_prev_woinf',
#  'median_income_prev_moe_inf',
#  'median_income_prev',
#  'median_income_moe_prev',
#  'median_income_moe_latest_per',
#  'median_income_moe_prev_per',
#  'nj_median_income_latest',
#  'nj_median_income_prev',
#  'usa_median_income_latest',
#  'usa_median_income_prev',
#  'median_income_change',
#  'nj_median_income_change',
#  'usa_median_income_change',
#  'population_latest',
#  'population_latest_moe',
#  'population_prev',
#  'population_prev_moe',
#  'population_moe_latest_per',
#  'population_moe_prev_per',
#  'nj_population_latest',
#  'nj_population_prev',
#  'usa_population_latest',
#  'usa_population_prev',
#  'population_change',
#  'nj_population_change',
#  'usa_population_change',
#  'ledgerstyle_x',
#  'median_age_latest',
#  'median_age_moe_latest',
#  'median_age_moe_per_latest',
# ...

# %%
merge3 = merge3.drop(['Id2', 'County_y', 'ledgerstyle_y'], axis=1)
merge3.rename(columns={'County_x': 'County', 'ledgerstyle_x': 'ledgerstyle'}, inplace=True)

# %%
merge3.head(5)
# Out:
#         GEOdisplaylabel      County               GEO.id     GEO.id2  \
# 0          Absecon city   Atlantic   0600000US3400100100  3400100100
# 1    Atlantic City city   Atlantic   0600000US3400102080  3400102080
# 2       Brigantine city   Atlantic   0600000US3400107810  3400107810
# 3         Buena borough   Atlantic   0600000US3400108680  3400108680
# 4  Buena Vista township   Atlantic   0600000US3400108710  3400108710
#
#                     GEOdisplaylabel_long median_income_latest  \
# 0          Absecon city, Atlantic County                63656
# 1    Atlantic City city, Atlantic County                25737
# 2       Brigantine city, Atlantic County                57031
# 3         Buena borough, Atlantic County                46169
# 4  Buena Vista township, Atlantic County                50421
#
#    median_income_latest_moe  median_income_prev_woinf  \
# 0                      9225                     69782
# 1                      1450                     30601
# ...

# %%
merge4 = pd.merge(merge3, poverty, left_on='GEO.id2', right_on='Id2', how='left')

# %%
len(merge4.index)
# Out:
# 586

# %%
list(merge4)
# Out:
# ['GEOdisplaylabel',
#  'County',
#  'GEO.id',
#  'GEO.id2',
#  'GEOdisplaylabel_long',
#  'median_income_latest',
#  'median_income_latest_moe',
#  'median_income_prev_woinf',
#  'median_income_prev_moe_inf',
#  'median_income_prev',
#  'median_income_moe_prev',
#  'median_income_moe_latest_per',
#  'median_income_moe_prev_per',
#  'nj_median_income_latest',
#  'nj_median_income_prev',
#  'usa_median_income_latest',
#  'usa_median_income_prev',
#  'median_income_change',
#  'nj_median_income_change',
#  'usa_median_income_change',
#  'population_latest',
#  'population_latest_moe',
#  'population_prev',
#  'population_prev_moe',
#  'population_moe_latest_per',
#  'population_moe_prev_per',
#  'nj_population_latest',
#  'nj_population_prev',
#  'usa_population_latest',
#  'usa_population_prev',
#  'population_change',
#  'nj_population_change',
#  'usa_population_change',
#  'ledgerstyle_x',
#  'median_age_latest',
#  'median_age_moe_latest',
#  'median_age_moe_per_latest',
# ...

# %%
merge4 = merge4.drop(['Id2', 'county', 'ledgerstyle_y'], axis=1)
merge4.rename(columns={'ledgerstyle_x': 'ledgerstyle'}, inplace=True)

# %%
merge4.head(5)
# Out:
#         GEOdisplaylabel      County               GEO.id     GEO.id2  \
# 0          Absecon city   Atlantic   0600000US3400100100  3400100100
# 1    Atlantic City city   Atlantic   0600000US3400102080  3400102080
# 2       Brigantine city   Atlantic   0600000US3400107810  3400107810
# 3         Buena borough   Atlantic   0600000US3400108680  3400108680
# 4  Buena Vista township   Atlantic   0600000US3400108710  3400108710
#
#                     GEOdisplaylabel_long median_income_latest  \
# 0          Absecon city, Atlantic County                63656
# 1    Atlantic City city, Atlantic County                25737
# 2       Brigantine city, Atlantic County                57031
# 3         Buena borough, Atlantic County                46169
# 4  Buena Vista township, Atlantic County                50421
#
#    median_income_latest_moe  median_income_prev_woinf  \
# 0                      9225                     69782
# 1                      1450                     30601
# ...

# %%
len(home_values.index)
# Out:
# 586

# %%
merge5 = pd.merge(merge4, home_values, left_on='GEO.id2', right_on='GEO.id2', how='left')

# %%
len(merge5.index)
# Out:
# 586

# %%
list(merge5)
# Out:
# ['GEOdisplaylabel_x',
#  'County_x',
#  'GEO.id_x',
#  'GEO.id2',
#  'GEOdisplaylabel_long_x',
#  'median_income_latest',
#  'median_income_latest_moe',
#  'median_income_prev_woinf',
#  'median_income_prev_moe_inf',
#  'median_income_prev',
#  'median_income_moe_prev',
#  'median_income_moe_latest_per',
#  'median_income_moe_prev_per',
#  'nj_median_income_latest',
#  'nj_median_income_prev',
#  'usa_median_income_latest',
#  'usa_median_income_prev',
#  'median_income_change',
#  'nj_median_income_change',
#  'usa_median_income_change',
#  'population_latest',
#  'population_latest_moe',
#  'population_prev',
#  'population_prev_moe',
#  'population_moe_latest_per',
#  'population_moe_prev_per',
#  'nj_population_latest',
#  'nj_population_prev',
#  'usa_population_latest',
#  'usa_population_prev',
#  'population_change',
#  'nj_population_change',
#  'usa_population_change',
#  'ledgerstyle',
#  'median_age_latest',
#  'median_age_moe_latest',
#  'median_age_moe_per_latest',
# ...

# %%
merge5 = merge5.drop(['GEOdisplaylabel_y', 'County_y', 'GEO.id_y', 'GEOdisplaylabel_long_y'], axis=1)
merge5.rename(columns={'GEOdisplaylabel_x': 'GEOdisplaylabel', 'County_x': 'County', 'GEO.id_x': 'GEO.id', 'GEOdisplaylabel_long_x': 'GEOdisplaylabel_long'}, inplace=True)

# %%
merge5.head(5)
# Out:
#         GEOdisplaylabel      County               GEO.id     GEO.id2  \
# 0          Absecon city   Atlantic   0600000US3400100100  3400100100
# 1    Atlantic City city   Atlantic   0600000US3400102080  3400102080
# 2       Brigantine city   Atlantic   0600000US3400107810  3400107810
# 3         Buena borough   Atlantic   0600000US3400108680  3400108680
# 4  Buena Vista township   Atlantic   0600000US3400108710  3400108710
#
#                     GEOdisplaylabel_long median_income_latest  \
# 0          Absecon city, Atlantic County                63656
# 1    Atlantic City city, Atlantic County                25737
# 2       Brigantine city, Atlantic County                57031
# 3         Buena borough, Atlantic County                46169
# 4  Buena Vista township, Atlantic County                50421
#
#    median_income_latest_moe  median_income_prev_woinf  \
# 0                      9225                     69782
# 1                      1450                     30601
# ...

# %%
len(home_costs.index)
# Out:
# 586

# %%
merge6 = pd.merge(merge5, home_costs, left_on='GEO.id2', right_on='GEO.id2', how='left')

# %%
len(merge6.index)
# Out:
# 586

# %%
merge6.head(5)
# Out:
#       GEOdisplaylabel_x    County_x             GEO.id_x     GEO.id2  \
# 0          Absecon city   Atlantic   0600000US3400100100  3400100100
# 1    Atlantic City city   Atlantic   0600000US3400102080  3400102080
# 2       Brigantine city   Atlantic   0600000US3400107810  3400107810
# 3         Buena borough   Atlantic   0600000US3400108680  3400108680
# 4  Buena Vista township   Atlantic   0600000US3400108710  3400108710
#
#                   GEOdisplaylabel_long_x median_income_latest  \
# 0          Absecon city, Atlantic County                63656
# 1    Atlantic City city, Atlantic County                25737
# 2       Brigantine city, Atlantic County                57031
# 3         Buena borough, Atlantic County                46169
# 4  Buena Vista township, Atlantic County                50421
#
#    median_income_latest_moe  median_income_prev_woinf  \
# 0                      9225                     69782
# 1                      1450                     30601
# ...

# %%
list(merge6)
# Out:
# ['GEOdisplaylabel_x',
#  'County_x',
#  'GEO.id_x',
#  'GEO.id2',
#  'GEOdisplaylabel_long_x',
#  'median_income_latest',
#  'median_income_latest_moe',
#  'median_income_prev_woinf',
#  'median_income_prev_moe_inf',
#  'median_income_prev',
#  'median_income_moe_prev',
#  'median_income_moe_latest_per',
#  'median_income_moe_prev_per',
#  'nj_median_income_latest',
#  'nj_median_income_prev',
#  'usa_median_income_latest',
#  'usa_median_income_prev',
#  'median_income_change',
#  'nj_median_income_change',
#  'usa_median_income_change',
#  'population_latest',
#  'population_latest_moe',
#  'population_prev',
#  'population_prev_moe',
#  'population_moe_latest_per',
#  'population_moe_prev_per',
#  'nj_population_latest',
#  'nj_population_prev',
#  'usa_population_latest',
#  'usa_population_prev',
#  'population_change',
#  'nj_population_change',
#  'usa_population_change',
#  'ledgerstyle',
#  'median_age_latest',
#  'median_age_moe_latest',
#  'median_age_moe_per_latest',
# ...

# %%
merge6 = merge6.drop(['GEOdisplaylabel_y', 'County_y', 'GEO.id_y', 'GEOdisplaylabel_long_y'], axis=1)
merge6.rename(columns={'GEOdisplaylabel_x': 'GEOdisplaylabel', 'County_x': 'County', 'GEO.id_x': 'GEO.id', 'GEOdisplaylabel_long_x': 'GEOdisplaylabel_long'}, inplace=True)

# %%
merge6.head(5)
# Out:
#         GEOdisplaylabel      County               GEO.id     GEO.id2  \
# 0          Absecon city   Atlantic   0600000US3400100100  3400100100
# 1    Atlantic City city   Atlantic   0600000US3400102080  3400102080
# 2       Brigantine city   Atlantic   0600000US3400107810  3400107810
# 3         Buena borough   Atlantic   0600000US3400108680  3400108680
# 4  Buena Vista township   Atlantic   0600000US3400108710  3400108710
#
#                     GEOdisplaylabel_long median_income_latest  \
# 0          Absecon city, Atlantic County                63656
# 1    Atlantic City city, Atlantic County                25737
# 2       Brigantine city, Atlantic County                57031
# 3         Buena borough, Atlantic County                46169
# 4  Buena Vista township, Atlantic County                50421
#
#    median_income_latest_moe  median_income_prev_woinf  \
# 0                      9225                     69782
# 1                      1450                     30601
# ...

# %%
len(commute.index)
# Out:
# 586

# %%
merge7 = pd.merge(merge6, commute, left_on='GEO.id2', right_on='GEO.id2', how='left')

# %%
len(merge7.index)
# Out:
# 586

# %%
list(merge7)
# Out:
# ['GEOdisplaylabel_x',
#  'County_x',
#  'GEO.id_x',
#  'GEO.id2',
#  'GEOdisplaylabel_long_x',
#  'median_income_latest',
#  'median_income_latest_moe',
#  'median_income_prev_woinf',
#  'median_income_prev_moe_inf',
#  'median_income_prev',
#  'median_income_moe_prev',
#  'median_income_moe_latest_per',
#  'median_income_moe_prev_per',
#  'nj_median_income_latest',
#  'nj_median_income_prev',
#  'usa_median_income_latest',
#  'usa_median_income_prev',
#  'median_income_change',
#  'nj_median_income_change',
#  'usa_median_income_change',
#  'population_latest',
#  'population_latest_moe',
#  'population_prev',
#  'population_prev_moe',
#  'population_moe_latest_per',
#  'population_moe_prev_per',
#  'nj_population_latest',
#  'nj_population_prev',
#  'usa_population_latest',
#  'usa_population_prev',
#  'population_change',
#  'nj_population_change',
#  'usa_population_change',
#  'ledgerstyle',
#  'median_age_latest',
#  'median_age_moe_latest',
#  'median_age_moe_per_latest',
# ...

# %%
merge7 = merge7.drop(['GEOdisplaylabel_y', 'County_y', 'GEO.id_y', 'GEOdisplaylabel_long_y'], axis=1)
merge7.rename(columns={'GEOdisplaylabel_x': 'GEOdisplaylabel', 'County_x': 'County', 'GEO.id_x': 'GEO.id', 'GEOdisplaylabel_long_x': 'GEOdisplaylabel_long'}, inplace=True)

# %%
merge7.to_csv('ultimate_census_data.csv', header=True, index=False)

# %%
merge7.head(5)
# Out:
#         GEOdisplaylabel      County               GEO.id     GEO.id2  \
# 0          Absecon city   Atlantic   0600000US3400100100  3400100100
# 1    Atlantic City city   Atlantic   0600000US3400102080  3400102080
# 2       Brigantine city   Atlantic   0600000US3400107810  3400107810
# 3         Buena borough   Atlantic   0600000US3400108680  3400108680
# 4  Buena Vista township   Atlantic   0600000US3400108710  3400108710
#
#                     GEOdisplaylabel_long median_income_latest  \
# 0          Absecon city, Atlantic County                63656
# 1    Atlantic City city, Atlantic County                25737
# 2       Brigantine city, Atlantic County                57031
# 3         Buena borough, Atlantic County                46169
# 4  Buena Vista township, Atlantic County                50421
#
#    median_income_latest_moe  median_income_prev_woinf  \
# 0                      9225                     69782
# 1                      1450                     30601
# ...

# %%
list(merge7)
# Out:
# ['GEOdisplaylabel',
#  'County',
#  'GEO.id',
#  'GEO.id2',
#  'GEOdisplaylabel_long',
#  'median_income_latest',
#  'median_income_latest_moe',
#  'median_income_prev_woinf',
#  'median_income_prev_moe_inf',
#  'median_income_prev',
#  'median_income_moe_prev',
#  'median_income_moe_latest_per',
#  'median_income_moe_prev_per',
#  'nj_median_income_latest',
#  'nj_median_income_prev',
#  'usa_median_income_latest',
#  'usa_median_income_prev',
#  'median_income_change',
#  'nj_median_income_change',
#  'usa_median_income_change',
#  'population_latest',
#  'population_latest_moe',
#  'population_prev',
#  'population_prev_moe',
#  'population_moe_latest_per',
#  'population_moe_prev_per',
#  'nj_population_latest',
#  'nj_population_prev',
#  'usa_population_latest',
#  'usa_population_prev',
#  'population_change',
#  'nj_population_change',
#  'usa_population_change',
#  'ledgerstyle',
#  'median_age_latest',
#  'median_age_moe_latest',
#  'median_age_moe_per_latest',
# ...
