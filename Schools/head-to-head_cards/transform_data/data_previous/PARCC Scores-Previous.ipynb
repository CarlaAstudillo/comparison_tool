# %%
import pandas as pd

# %%
math_grade3 = pd.read_excel('MAT03.xlsx', skiprows=2, skipfooter=2)
math_grade4 = pd.read_excel('MAT04.xlsx', skiprows=2, skipfooter=2)
math_grade5 = pd.read_excel('MAT05.xlsx', skiprows=2, skipfooter=2)
math_grade6 = pd.read_excel('MAT06.xlsx', skiprows=2, skipfooter=2)
math_grade7 = pd.read_excel('MAT07.xlsx', skiprows=2, skipfooter=2)
math_grade8 = pd.read_excel('MAT08.xlsx', skiprows=2, skipfooter=2)
math_gradealg = pd.read_excel('MATALG1.xlsx', skiprows=2, skipfooter=2)
math_gradealg2 = pd.read_excel('MATALG2.xlsx', skiprows=2, skipfooter=2)
math_gradegeo = pd.read_excel('MATGEO.xlsx', skiprows=2, skipfooter=2)

# %%
math_grade3['GRADE'] = '3'
math_grade4['GRADE'] = '4'
math_grade5['GRADE'] = '5'
math_grade6['GRADE'] = '6'
math_grade7['GRADE'] = '7'
math_grade8['GRADE'] = '8'
math_gradealg['GRADE'] = '9 and Algebra I'
math_gradealg2['GRADE'] = '10 and Algebra II'
math_gradegeo['GRADE'] = '11 and Geometry'

# %%
math_grade3
# Out:
#       COUNTY CODE COUNTY NAME DISTRICT CODE  DISTRICT NAME  SCHOOL CODE  \
# 0              01    ATLANTIC          0010   ABSECON CITY         60.0
# 1              01    ATLANTIC          0010   ABSECON CITY         60.0
# 2              01    ATLANTIC          0010   ABSECON CITY         60.0
# 3              01    ATLANTIC          0010   ABSECON CITY         60.0
# 4              01    ATLANTIC          0010   ABSECON CITY         60.0
# 5              01    ATLANTIC          0010   ABSECON CITY         60.0
# 6              01    ATLANTIC          0010   ABSECON CITY         60.0
# 7              01    ATLANTIC          0010   ABSECON CITY         60.0
# 8              01    ATLANTIC          0010   ABSECON CITY         60.0
# 9              01    ATLANTIC          0010   ABSECON CITY         60.0
# 10             01    ATLANTIC          0010   ABSECON CITY         60.0
# 11             01    ATLANTIC          0010   ABSECON CITY         60.0
# 12             01    ATLANTIC          0010   ABSECON CITY         60.0
# 13             01    ATLANTIC          0010   ABSECON CITY         60.0
# 14             01    ATLANTIC          0010   ABSECON CITY          NaN
# 15             01    ATLANTIC          0010   ABSECON CITY          NaN
# 16             01    ATLANTIC          0010   ABSECON CITY          NaN
# 17             01    ATLANTIC          0010   ABSECON CITY          NaN
# 18             01    ATLANTIC          0010   ABSECON CITY          NaN
# 19             01    ATLANTIC          0010   ABSECON CITY          NaN
# 20             01    ATLANTIC          0010   ABSECON CITY          NaN
# 21             01    ATLANTIC          0010   ABSECON CITY          NaN
# 22             01    ATLANTIC          0010   ABSECON CITY          NaN
# 23             01    ATLANTIC          0010   ABSECON CITY          NaN
# 24             01    ATLANTIC          0010   ABSECON CITY          NaN
# 25             01    ATLANTIC          0010   ABSECON CITY          NaN
# 26             01    ATLANTIC          0010   ABSECON CITY          NaN
# 27             01    ATLANTIC          0010   ABSECON CITY          NaN
# 28             01    ATLANTIC          0110  ATLANTIC CITY         30.0
# 29             01    ATLANTIC          0110  ATLANTIC CITY         30.0
# ...           ...         ...           ...            ...          ...
# 22921         DFG         NaN           NaN            NaN          NaN
# 22922         DFG         NaN           NaN            NaN          NaN
# 22923         DFG         NaN           NaN            NaN          NaN
# 22924         DFG         NaN           NaN            NaN          NaN
# 22925         DFG         NaN           NaN            NaN          NaN
# 22926         DFG         NaN           NaN            NaN          NaN
# 22927         DFG         NaN           NaN            NaN          NaN
# 22928         DFG         NaN           NaN            NaN          NaN
# 22929         DFG         NaN           NaN            NaN          NaN
# 22930         DFG         NaN           NaN            NaN          NaN
# 22931         DFG         NaN           NaN            NaN          NaN
# 22932         DFG         NaN           NaN            NaN          NaN
# 22933         DFG         NaN           NaN            NaN          NaN
# 22934         DFG         NaN           NaN            NaN          NaN
# 22935       STATE         NaN           NaN            NaN          NaN
# 22936       STATE         NaN           NaN            NaN          NaN
# 22937       STATE         NaN           NaN            NaN          NaN
# 22938       STATE         NaN           NaN            NaN          NaN
# 22939       STATE         NaN           NaN            NaN          NaN
# 22940       STATE         NaN           NaN            NaN          NaN
# 22941       STATE         NaN           NaN            NaN          NaN
# 22942       STATE         NaN           NaN            NaN          NaN
# 22943       STATE         NaN           NaN            NaN          NaN
# 22944       STATE         NaN           NaN            NaN          NaN
# 22945       STATE         NaN           NaN            NaN          NaN
# 22946       STATE         NaN           NaN            NaN          NaN
# 22947       STATE         NaN           NaN            NaN          NaN
# 22948       STATE         NaN           NaN            NaN          NaN
# 22949       STATE         NaN           NaN            NaN          NaN
# 22950       STATE         NaN           NaN            NaN          NaN
#
#                    SCHOOL NAME  DFG        SUBGROUP  \
# 0               H ASHTON MARSH   CD           TOTAL
# 1               H ASHTON MARSH   CD  RACE/ETHNICITY
# 2               H ASHTON MARSH   CD  RACE/ETHNICITY
# 3               H ASHTON MARSH   CD  RACE/ETHNICITY
# 4               H ASHTON MARSH   CD  RACE/ETHNICITY
# 5               H ASHTON MARSH   CD  RACE/ETHNICITY
# 6               H ASHTON MARSH   CD          GENDER
# 7               H ASHTON MARSH   CD          GENDER
# 8               H ASHTON MARSH   CD        SUBGROUP
# 9               H ASHTON MARSH   CD        SUBGROUP
# 10              H ASHTON MARSH   CD        SUBGROUP
# 11              H ASHTON MARSH   CD        SUBGROUP
# 12              H ASHTON MARSH   CD        SUBGROUP
# 13              H ASHTON MARSH   CD        SUBGROUP
# 14                         NaN   CD           TOTAL
# 15                         NaN   CD  RACE/ETHNICITY
# 16                         NaN   CD  RACE/ETHNICITY
# 17                         NaN   CD  RACE/ETHNICITY
# 18                         NaN   CD  RACE/ETHNICITY
# 19                         NaN   CD  RACE/ETHNICITY
# 20                         NaN   CD          GENDER
# 21                         NaN   CD          GENDER
# 22                         NaN   CD        SUBGROUP
# 23                         NaN   CD        SUBGROUP
# 24                         NaN   CD        SUBGROUP
# 25                         NaN   CD        SUBGROUP
# 26                         NaN   CD        SUBGROUP
# 27                         NaN   CD        SUBGROUP
# 28     SOVEREIGN AVENUE SCHOOL    A           TOTAL
# 29     SOVEREIGN AVENUE SCHOOL    A  RACE/ETHNICITY
# ...                        ...  ...             ...
# 22921                      NaN    R  RACE/ETHNICITY
# 22922                      NaN    R  RACE/ETHNICITY
# 22923                      NaN    R  RACE/ETHNICITY
# 22924                      NaN    R  RACE/ETHNICITY
# 22925                      NaN    R  RACE/ETHNICITY
# 22926                      NaN    R  RACE/ETHNICITY
# 22927                      NaN    R          GENDER
# 22928                      NaN    R          GENDER
# 22929                      NaN    R        SUBGROUP
# 22930                      NaN    R        SUBGROUP
# 22931                      NaN    R        SUBGROUP
# 22932                      NaN    R        SUBGROUP
# 22933                      NaN    R        SUBGROUP
# 22934                      NaN    R        SUBGROUP
# 22935                      NaN  NaN           TOTAL
# 22936                      NaN  NaN  RACE/ETHNICITY
# 22937                      NaN  NaN  RACE/ETHNICITY
# 22938                      NaN  NaN  RACE/ETHNICITY
# 22939                      NaN  NaN  RACE/ETHNICITY
# 22940                      NaN  NaN  RACE/ETHNICITY
# 22941                      NaN  NaN  RACE/ETHNICITY
# 22942                      NaN  NaN  RACE/ETHNICITY
# 22943                      NaN  NaN          GENDER
# 22944                      NaN  NaN          GENDER
# 22945                      NaN  NaN        SUBGROUP
# 22946                      NaN  NaN        SUBGROUP
# 22947                      NaN  NaN        SUBGROUP
# 22948                      NaN  NaN        SUBGROUP
# 22949                      NaN  NaN        SUBGROUP
# 22950                      NaN  NaN        SUBGROUP
#
#                                    SUBGROUP_TYPE REGISTERED TO TEST  \
# 0                                   ALL STUDENTS                 90
# 1                                          WHITE                NaN
# 2                               AFRICAN AMERICAN                NaN
# 3                                          ASIAN                NaN
# 4                                       HISPANIC                NaN
# 5                                          OTHER                NaN
# 6                                           MALE                NaN
# 7                                         FEMALE                NaN
# 8                      STUDENTS WITH DISABLITIES                NaN
# 9                      ENGLISH LANGUAGE LEARNERS                NaN
# 10                                 CURRENT - ELL                NaN
# 11                                  FORMER - ELL                NaN
# 12                    ECONOMICALLY DISADVANTAGED                NaN
# 13                       NON ECON. DISADVANTAGED                NaN
# 14                                  ALL STUDENTS                 90
# 15                                         WHITE                NaN
# 16                              AFRICAN AMERICAN                NaN
# 17                                         ASIAN                NaN
# 18                                      HISPANIC                NaN
# 19                                         OTHER                NaN
# 20                                          MALE                NaN
# 21                                        FEMALE                NaN
# 22                     STUDENTS WITH DISABLITIES                NaN
# 23                     ENGLISH LANGUAGE LEARNERS                NaN
# 24                                 CURRENT - ELL                NaN
# 25                                  FORMER - ELL                NaN
# 26                    ECONOMICALLY DISADVANTAGED                NaN
# 27                       NON ECON. DISADVANTAGED                NaN
# 28                                  ALL STUDENTS                  *
# 29                              AFRICAN AMERICAN                NaN
# ...                                          ...                ...
# 22921                           AFRICAN AMERICAN                NaN
# 22922                                      ASIAN                NaN
# 22923                            AMERICAN INDIAN                NaN
# 22924                                   HISPANIC                NaN
# 22925  NATIVE HAWAIIAN OR OTHER PACIFIC ISLANDER                NaN
# 22926                                      OTHER                NaN
# 22927                                       MALE                NaN
# 22928                                     FEMALE                NaN
# 22929                  STUDENTS WITH DISABLITIES                NaN
# 22930                  ENGLISH LANGUAGE LEARNERS                NaN
# 22931                              CURRENT - ELL                NaN
# 22932                               FORMER - ELL                NaN
# 22933                 ECONOMICALLY DISADVANTAGED                NaN
# 22934                    NON ECON. DISADVANTAGED                NaN
# 22935                               ALL STUDENTS             101833
# 22936                                      WHITE              45965
# 22937                           AFRICAN AMERICAN              15658
# 22938                                      ASIAN               9996
# 22939                            AMERICAN INDIAN                  *
# 22940                                   HISPANIC              27810
# 22941  NATIVE HAWAIIAN OR OTHER PACIFIC ISLANDER                  *
# 22942                                      OTHER               2033
# 22943                                       MALE              51984
# 22944                                     FEMALE              49849
# 22945                  STUDENTS WITH DISABLITIES              15645
# 22946                  ENGLISH LANGUAGE LEARNERS               9911
# 22947                              CURRENT - ELL               7214
# 22948                               FORMER - ELL               2697
# 22949                 ECONOMICALLY DISADVANTAGED              41841
# 22950                    NON ECON. DISADVANTAGED              59992
#
#       NOT TESTED ** (See Below) VALID SCORES MEAN SCALE SCORE L1 PERCENT  \
# 0                            22           68              739        4.4
# 1                           NaN           38              744        2.6
# 2                           NaN           13              721        7.7
# 3                           NaN            *                *          *
# 4                           NaN            *                *          *
# 5                           NaN            *                *          *
# 6                           NaN           37              743          0
# 7                           NaN           31              735        9.7
# 8                           NaN            *                *          *
# 9                           NaN           12              736        8.3
# 10                          NaN            *                *          *
# 11                          NaN            *                *          *
# 12                          NaN           31              730        6.5
# 13                          NaN           37              747        2.7
# 14                           22           68              739        4.4
# 15                          NaN           38              744        2.6
# 16                          NaN           13              721        7.7
# 17                          NaN            *                *          *
# 18                          NaN            *                *          *
# 19                          NaN            *                *          *
# 20                          NaN           37              743          0
# 21                          NaN           31              735        9.7
# 22                          NaN            *                *          *
# 23                          NaN           12              736        8.3
# 24                          NaN            *                *          *
# 25                          NaN            *                *          *
# 26                          NaN           31              730        6.5
# 27                          NaN           37              747        2.7
# 28                            *           76              737       13.2
# 29                          NaN            *                *          *
# ...                         ...          ...              ...        ...
# 22921                       NaN         1842              741        7.9
# 22922                       NaN          183              775         .5
# 22923                       NaN            *                *          *
# 22924                       NaN          935              741        9.6
# 22925                       NaN            *                *          *
# 22926                       NaN           64              761        3.1
# 22927                       NaN         1635              745        7.9
# 22928                       NaN         1746              746        6.7
# 22929                       NaN          271              725       21.4
# 22930                       NaN           89              731       16.9
# 22931                       NaN           67              724       20.9
# 22932                       NaN           22              751        4.5
# 22933                       NaN         2410              740        8.5
# 22934                       NaN          971              758        4.3
# 22935                      5901        95932              745        8.3
# 22936                      3446        42519              752          4
# 22937                       965        14693              727       17.9
# 22938                       196         9800              772        1.6
# 22939                         *          128              739       14.1
# 22940                      1137        26673              732       12.5
# 22941                         *          226              756          4
# 22942                       140         1893              751        6.7
# 22943                      3053        48931              745        9.3
# 22944                      2848        47001              745        7.3
# 22945                      1564        14081              726         22
# 22946                       190         9721              729       15.4
# 22947                       154         7060              724       18.5
# 22948                        36         2661              742        7.3
# 22949                      1997        39844              730       14.7
# 22950                      3904        56088              755        3.8
#
#       L2 PERCENT L3 PERCENT L4 PERCENT L5 PERCENT GRADE
# 0           23.5       30.9       38.2        2.9     3
# 1           18.4       36.8       39.5        2.6     3
# 2           46.2       23.1       23.1          0     3
# 3              *          *          *          *     3
# 4              *          *          *          *     3
# 5              *          *          *          *     3
# 6           21.6       40.5       35.1        2.7     3
# 7           25.8       19.4       41.9        3.2     3
# 8              *          *          *          *     3
# 9             25         25       41.7          0     3
# 10             *          *          *          *     3
# 11             *          *          *          *     3
# 12          38.7       25.8       25.8        3.2     3
# 13          10.8       35.1       48.6        2.7     3
# 14          23.5       30.9       38.2        2.9     3
# 15          18.4       36.8       39.5        2.6     3
# 16          46.2       23.1       23.1          0     3
# 17             *          *          *          *     3
# 18             *          *          *          *     3
# 19             *          *          *          *     3
# 20          21.6       40.5       35.1        2.7     3
# 21          25.8       19.4       41.9        3.2     3
# 22             *          *          *          *     3
# 23            25         25       41.7          0     3
# 24             *          *          *          *     3
# 25             *          *          *          *     3
# 26          38.7       25.8       25.8        3.2     3
# 27          10.8       35.1       48.6        2.7     3
# 28          13.2       36.8       31.6        5.3     3
# 29             *          *          *          *     3
# ...          ...        ...        ...        ...   ...
# 22921       22.1       30.9       33.2        5.8     3
# 22922        3.3       16.9       50.3         29     3
# 22923          *          *          *          *     3
# 22924         19       31.7       34.4        5.2     3
# 22925          *          *          *          *     3
# 22926        9.4       26.6       42.2       18.8     3
# 22927         19       28.3       36.1        8.7     3
# 22928       18.3       30.3       36.2        8.5     3
# 22929       31.4       27.3       16.6        3.3     3
# 22930       24.7       33.7       21.3        3.4     3
# 22931       26.9       34.3       16.4        1.5     3
# 22932       18.2       31.8       36.4        9.1     3
# 22933       21.6       31.5       32.9        5.5     3
# 22934       11.4       23.8       44.1       16.4     3
# 22935       18.5       28.3       36.9          8     3
# 22936         13       27.7       46.5        8.9     3
# 22937       28.5         30       21.7        1.9     3
# 22938        5.1         16       48.6       28.8     3
# 22939       18.8       27.3       28.9       10.9     3
# 22940         27         33       25.3        2.2     3
# 22941       10.6       25.7       47.3       12.4     3
# 22942       14.9       25.4       41.7       11.3     3
# 22943       18.5       27.2       36.3        8.6     3
# 22944       18.4       29.3       37.5        7.4     3
# 22945       28.3       25.4       21.3          3     3
# 22946       30.7       30.6       20.5        2.8     3
# 22947       34.7         30       15.2        1.5     3
# 22948         20       32.2       34.5          6     3
# 22949       28.1       31.9       23.3          2     3
# 22950       11.6       25.7       46.6       12.3     3
#
# [22951 rows x 19 columns]

# %%
#Concat all scores

math_grade_all = pd.concat([math_grade3, math_grade4, math_grade5, math_grade6, math_grade7, math_grade8, math_gradealg, math_gradealg2, math_gradegeo], axis=0)

# %%
len(math_grade3.index)
# Out:
# 22951

# %%
len(math_grade4.index)
# Out:
# 22324

# %%
len(math_grade_all.index)
# Out:
# 152752

# %%
math_grade4filter = math_grade_all[(math_grade_all['SCHOOL NAME'] == "WILLIAM H. ROSS III SCHOOL")]
math_grade4filter
# Out:
#     COUNTY CODE COUNTY NAME DISTRICT CODE DISTRICT NAME  SCHOOL CODE  \
# 479          01    ATLANTIC          3020  MARGATE CITY         25.0
# 480          01    ATLANTIC          3020  MARGATE CITY         25.0
# 481          01    ATLANTIC          3020  MARGATE CITY         25.0
# 482          01    ATLANTIC          3020  MARGATE CITY         25.0
# 483          01    ATLANTIC          3020  MARGATE CITY         25.0
# 484          01    ATLANTIC          3020  MARGATE CITY         25.0
# 485          01    ATLANTIC          3020  MARGATE CITY         25.0
# 486          01    ATLANTIC          3020  MARGATE CITY         25.0
# 487          01    ATLANTIC          3020  MARGATE CITY         25.0
# 488          01    ATLANTIC          3020  MARGATE CITY         25.0
# 450          01    ATLANTIC          3020  MARGATE CITY         25.0
# 451          01    ATLANTIC          3020  MARGATE CITY         25.0
# 452          01    ATLANTIC          3020  MARGATE CITY         25.0
# 453          01    ATLANTIC          3020  MARGATE CITY         25.0
# 454          01    ATLANTIC          3020  MARGATE CITY         25.0
# 455          01    ATLANTIC          3020  MARGATE CITY         25.0
# 456          01    ATLANTIC          3020  MARGATE CITY         25.0
#
#                     SCHOOL NAME DFG        SUBGROUP  \
# 479  WILLIAM H. ROSS III SCHOOL  DE           TOTAL
# 480  WILLIAM H. ROSS III SCHOOL  DE  RACE/ETHNICITY
# 481  WILLIAM H. ROSS III SCHOOL  DE  RACE/ETHNICITY
# 482  WILLIAM H. ROSS III SCHOOL  DE  RACE/ETHNICITY
# 483  WILLIAM H. ROSS III SCHOOL  DE  RACE/ETHNICITY
# 484  WILLIAM H. ROSS III SCHOOL  DE          GENDER
# 485  WILLIAM H. ROSS III SCHOOL  DE          GENDER
# 486  WILLIAM H. ROSS III SCHOOL  DE        SUBGROUP
# 487  WILLIAM H. ROSS III SCHOOL  DE        SUBGROUP
# 488  WILLIAM H. ROSS III SCHOOL  DE        SUBGROUP
# 450  WILLIAM H. ROSS III SCHOOL  DE           TOTAL
# 451  WILLIAM H. ROSS III SCHOOL  DE  RACE/ETHNICITY
# 452  WILLIAM H. ROSS III SCHOOL  DE          GENDER
# 453  WILLIAM H. ROSS III SCHOOL  DE          GENDER
# 454  WILLIAM H. ROSS III SCHOOL  DE        SUBGROUP
# 455  WILLIAM H. ROSS III SCHOOL  DE        SUBGROUP
# 456  WILLIAM H. ROSS III SCHOOL  DE        SUBGROUP
#
#                   SUBGROUP_TYPE REGISTERED TO TEST NOT TESTED ** (See Below)  \
# 479                ALL STUDENTS                  *                         *
# 480                       WHITE                NaN                       NaN
# 481             AMERICAN INDIAN                NaN                       NaN
# 482                    HISPANIC                NaN                       NaN
# 483                       OTHER                NaN                       NaN
# 484                        MALE                NaN                       NaN
# 485                      FEMALE                NaN                       NaN
# 486   STUDENTS WITH DISABLITIES                NaN                       NaN
# 487  ECONOMICALLY DISADVANTAGED                NaN                       NaN
# 488     NON ECON. DISADVANTAGED                NaN                       NaN
# 450                ALL STUDENTS                  *                         *
# 451                       WHITE                NaN                       NaN
# 452                        MALE                NaN                       NaN
# 453                      FEMALE                NaN                       NaN
# 454   STUDENTS WITH DISABLITIES                NaN                       NaN
# 455  ECONOMICALLY DISADVANTAGED                NaN                       NaN
# 456     NON ECON. DISADVANTAGED                NaN                       NaN
#
#     VALID SCORES MEAN SCALE SCORE L1 PERCENT L2 PERCENT L3 PERCENT L4 PERCENT  \
# 479           40              766          0       12.5         15       52.5
# 480           31              767          0       12.9        9.7       58.1
# 481            *                *          *          *          *          *
# 482            *                *          *          *          *          *
# 483            *                *          *          *          *          *
# 484           27              768          0       11.1       14.8       51.9
# 485           13              760          0       15.4       15.4       53.8
# 486            *                *          *          *          *          *
# 487            *                *          *          *          *          *
# 488            *                *          *          *          *          *
# 450           38              745          0       18.4       42.1       36.8
# 451           38              745          0       18.4       42.1       36.8
# 452           20              743          0         15         50         35
# 453           18              747          0       22.2       33.3       38.9
# 454            *                *          *          *          *          *
# 455            *                *          *          *          *          *
# 456            *                *          *          *          *          *
#
#     L5 PERCENT GRADE
# 479         20     3
# 480       19.4     3
# 481          *     3
# 482          *     3
# 483          *     3
# 484       22.2     3
# 485       15.4     3
# 486          *     3
# 487          *     3
# 488          *     3
# 450        2.6     4
# 451        2.6     4
# 452          0     4
# 453        5.6     4
# 454          *     4
# 455          *     4
# 456          *     4

# %%
#Filter stuff DFG-- not designated out
math_grade_all_nodfg = math_grade_all[(math_grade_all['COUNTY CODE'] != "DFG")]

# %%
#math_grade_all_nodfg

math_grade_all_nodfg['COUNTY CODE'].unique()
# Out:
# array([u'01', u'03', u'05', u'07', u'09', u'11', u'13', u'15', u'17',
#        u'19', u'21', u'23', u'25', u'27', u'29', u'31', u'33', u'35',
#        u'37', u'39', u'41', u'80', u'STATE'], dtype=object)

# %%
len(math_grade_all_nodfg.index)
# Out:
# 151088

# %%
#Filter statewide stuff
math_grade_state = math_grade_all[(math_grade_all['COUNTY CODE'] == "STATE")]

math_grade_state.to_csv('NJ_statewide.csv')

# %%
math_grade_clean = math_grade_all_nodfg[(math_grade_all_nodfg['COUNTY CODE'] != "STATE")]

# %%
len(math_grade_clean.index)
# Out:
# 150920

# %%
math_grade_clean['COUNTY CODE'].unique()
# Out:
# array([u'01', u'03', u'05', u'07', u'09', u'11', u'13', u'15', u'17',
#        u'19', u'21', u'23', u'25', u'27', u'29', u'31', u'33', u'35',
#        u'37', u'39', u'41', u'80'], dtype=object)

# %%
math_grade_clean.to_csv('math_allgrades2015.csv', header=True)

# %%
math_grade_all_withasterisk = math_grade_clean[(math_grade_clean['SUBGROUP'] == "TOTAL")]

# %%
len(math_grade_all_withasterisk.index)
# Out:
# 12583

# %%
math_grade_all_total = math_grade_all_withasterisk[(math_grade_all_withasterisk['L1 PERCENT'] != "*")]

# %%
len(math_grade_all_total.index)
# Out:
# 12015

# %%
math_grade4filter = math_grade_all_total[(math_grade_all_total['SCHOOL NAME'] == "WILLIAM H. ROSS III SCHOOL")]
math_grade4filter
# Out:
#     COUNTY CODE COUNTY NAME DISTRICT CODE DISTRICT NAME  SCHOOL CODE  \
# 479          01    ATLANTIC          3020  MARGATE CITY         25.0
# 450          01    ATLANTIC          3020  MARGATE CITY         25.0
#
#                     SCHOOL NAME DFG SUBGROUP SUBGROUP_TYPE REGISTERED TO TEST  \
# 479  WILLIAM H. ROSS III SCHOOL  DE    TOTAL  ALL STUDENTS                  *
# 450  WILLIAM H. ROSS III SCHOOL  DE    TOTAL  ALL STUDENTS                  *
#
#     NOT TESTED ** (See Below) VALID SCORES MEAN SCALE SCORE L1 PERCENT  \
# 479                         *           40              766          0
# 450                         *           38              745          0
#
#     L2 PERCENT L3 PERCENT L4 PERCENT L5 PERCENT GRADE
# 479       12.5         15       52.5         20     3
# 450       18.4       42.1       36.8        2.6     4

# %%
math_grade_all_total.head()
# Out:
#    COUNTY CODE COUNTY NAME DISTRICT CODE  DISTRICT NAME  SCHOOL CODE  \
# 0           01    ATLANTIC          0010   ABSECON CITY         60.0
# 14          01    ATLANTIC          0010   ABSECON CITY          NaN
# 28          01    ATLANTIC          0110  ATLANTIC CITY         30.0
# 41          01    ATLANTIC          0110  ATLANTIC CITY         50.0
# 54          01    ATLANTIC          0110  ATLANTIC CITY         60.0
#
#                 SCHOOL NAME DFG SUBGROUP SUBGROUP_TYPE REGISTERED TO TEST  \
# 0            H ASHTON MARSH  CD    TOTAL  ALL STUDENTS                 90
# 14                      NaN  CD    TOTAL  ALL STUDENTS                 90
# 28  SOVEREIGN AVENUE SCHOOL   A    TOTAL  ALL STUDENTS                  *
# 41   CHELSEA HEIGHTS SCHOOL   A    TOTAL  ALL STUDENTS                  *
# 54      TEXAS AVENUE SCHOOL   A    TOTAL  ALL STUDENTS                  *
#
#    NOT TESTED ** (See Below) VALID SCORES MEAN SCALE SCORE L1 PERCENT  \
# 0                         22           68              739        4.4
# 14                        22           68              739        4.4
# 28                         *           76              737       13.2
# 41                         *           37              739        2.7
# 54                         *           74              726       14.9
#
#    L2 PERCENT L3 PERCENT L4 PERCENT L5 PERCENT GRADE
# 0        23.5       30.9       38.2        2.9     3
# 14       23.5       30.9       38.2        2.9     3
# 28       13.2       36.8       31.6        5.3     3
# 41         27       35.1       32.4        2.7     3
# 54       39.2       31.1       12.2        2.7     3

# %%
math_grade_all_total['SCHOOL NAME'] =  math_grade_all_total['SCHOOL NAME'].fillna('DISTRICT WIDE')
# Out:
# /Users/castudi1/miniconda2/envs/lovepandas/lib/python2.7/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
math_grade_all_total.head(10)
# Out:
#     COUNTY CODE COUNTY NAME DISTRICT CODE  DISTRICT NAME  SCHOOL CODE  \
# 0            01    ATLANTIC          0010   ABSECON CITY         60.0
# 14           01    ATLANTIC          0010   ABSECON CITY          NaN
# 28           01    ATLANTIC          0110  ATLANTIC CITY         30.0
# 41           01    ATLANTIC          0110  ATLANTIC CITY         50.0
# 54           01    ATLANTIC          0110  ATLANTIC CITY         60.0
# 67           01    ATLANTIC          0110  ATLANTIC CITY         70.0
# 80           01    ATLANTIC          0110  ATLANTIC CITY         80.0
# 92           01    ATLANTIC          0110  ATLANTIC CITY        100.0
# 105          01    ATLANTIC          0110  ATLANTIC CITY        120.0
# 120          01    ATLANTIC          0110  ATLANTIC CITY        140.0
#
#                                  SCHOOL NAME DFG SUBGROUP SUBGROUP_TYPE  \
# 0                             H ASHTON MARSH  CD    TOTAL  ALL STUDENTS
# 14                             DISTRICT WIDE  CD    TOTAL  ALL STUDENTS
# 28                   SOVEREIGN AVENUE SCHOOL   A    TOTAL  ALL STUDENTS
# 41                    CHELSEA HEIGHTS SCHOOL   A    TOTAL  ALL STUDENTS
# 54                       TEXAS AVENUE SCHOOL   A    TOTAL  ALL STUDENTS
# 67                    NEW YORK AVENUE SCHOOL   A    TOTAL  ALL STUDENTS
# 80                     UPTOWN SCHOOL COMPLEX   A    TOTAL  ALL STUDENTS
# 92                   PENNSYLVANIA AVE SCHOOL   A    TOTAL  ALL STUDENTS
# 105                   RICHMOND AVENUE SCHOOL   A    TOTAL  ALL STUDENTS
# 120  DR MARTIN LUTHER KING JR SCHOOL COMPLEX   A    TOTAL  ALL STUDENTS
#
#     REGISTERED TO TEST NOT TESTED ** (See Below) VALID SCORES  \
# 0                   90                        22           68
# 14                  90                        22           68
# 28                   *                         *           76
# 41                   *                         *           37
# 54                   *                         *           74
# 67                   *                         *           58
# 80                   *                         *           63
# 92                   *                         *           52
# 105                  *                         *           56
# 120                  *                         *           79
#
#     MEAN SCALE SCORE L1 PERCENT L2 PERCENT L3 PERCENT L4 PERCENT L5 PERCENT  \
# 0                739        4.4       23.5       30.9       38.2        2.9
# 14               739        4.4       23.5       30.9       38.2        2.9
# 28               737       13.2       13.2       36.8       31.6        5.3
# 41               739        2.7         27       35.1       32.4        2.7
# 54               726       14.9       39.2       31.1       12.2        2.7
# 67               716       24.1       39.7       24.1       12.1          0
# 80               725       22.2       20.6       38.1       14.3        4.8
# 92               725       19.2       30.8       28.8       17.3        3.8
# 105              734        5.4       32.1       39.3       23.2          0
# 120              709       35.4       27.8       32.9        3.8          0
#
#     GRADE
# 0       3
# 14      3
# 28      3
# 41      3
# 54      3
# 67      3
# 80      3
# 92      3
# 105     3
# 120     3

# %%
math_grade4filter = math_grade_all_total[(math_grade_all_total['SCHOOL NAME'] == "WILLIAM H. ROSS III SCHOOL")]

math_grade_all_total.to_csv('math_allgrades_total2015-2.csv', header=True)
math_grade4filter
# Out:
#     COUNTY CODE COUNTY NAME DISTRICT CODE DISTRICT NAME  SCHOOL CODE  \
# 479          01    ATLANTIC          3020  MARGATE CITY         25.0
# 450          01    ATLANTIC          3020  MARGATE CITY         25.0
#
#                     SCHOOL NAME DFG SUBGROUP SUBGROUP_TYPE REGISTERED TO TEST  \
# 479  WILLIAM H. ROSS III SCHOOL  DE    TOTAL  ALL STUDENTS                  *
# 450  WILLIAM H. ROSS III SCHOOL  DE    TOTAL  ALL STUDENTS                  *
#
#     NOT TESTED ** (See Below) VALID SCORES MEAN SCALE SCORE L1 PERCENT  \
# 479                         *           40              766          0
# 450                         *           38              745          0
#
#     L2 PERCENT L3 PERCENT L4 PERCENT L5 PERCENT GRADE
# 479       12.5         15       52.5         20     3
# 450       18.4       42.1       36.8        2.6     4

# %%
la_grade3 = pd.read_excel('ELA03.xlsx', skiprows=2, skipfooter=2)
la_grade4 = pd.read_excel('ELA04.xlsx', skiprows=2, skipfooter=2)
la_grade5 = pd.read_excel('ELA05.xlsx', skiprows=2, skipfooter=2)
la_grade6 = pd.read_excel('ELA06.xlsx', skiprows=2, skipfooter=2)
la_grade7 = pd.read_excel('ELA07.xlsx', skiprows=2, skipfooter=2)
la_grade8 = pd.read_excel('ELA08.xlsx', skiprows=2, skipfooter=2)
la_grade9 = pd.read_excel('ELA09.xlsx', skiprows=2, skipfooter=2)
la_grade10 = pd.read_excel('ELA10.xlsx', skiprows=2, skipfooter=2)
la_grade11 = pd.read_excel('ELA11.xlsx', skiprows=2, skipfooter=2)

# %%
la_grade3['GRADE'] = '3'
la_grade4['GRADE'] = '4'
la_grade5['GRADE'] = '5'
la_grade6['GRADE'] = '6'
la_grade7['GRADE'] = '7'
la_grade8['GRADE'] = '8'
la_grade9['GRADE'] = '9 and Algebra I'
la_grade10['GRADE'] = '10 and Algebra II'
la_grade11['GRADE'] = '11 and Geometry'

# %%
la_grade_all = pd.concat([la_grade3, la_grade4, la_grade5, la_grade6, la_grade7, la_grade8, la_grade9, la_grade10, la_grade11], axis=0)

# %%
#Filter stuff DFG-- not designated out
la_grade_all_nodfg = la_grade_all[(la_grade_all['COUNTY CODE'] != "DFG")]

# %%
len(la_grade_all.index)
# Out:
# 138037

# %%
len(la_grade_all_nodfg.index)
# Out:
# 136536

# %%
la_grade_clean = la_grade_all_nodfg[(la_grade_all_nodfg['COUNTY CODE'] != "STATE")]

# %%
len(la_grade_clean.index)
# Out:
# 136392

# %%
la_grade_clean['COUNTY CODE'].unique()
# Out:
# array([u'01', u'03', u'05', u'07', u'09', u'11', u'13', u'15', u'17',
#        u'19', u'21', u'23', u'25', u'27', u'29', u'31', u'33', u'35',
#        u'37', u'39', u'41', u'80'], dtype=object)

# %%
la_grade_clean.to_csv('la_allgrades2015.csv', header=True)

# %%
#la_grade4filter = la_grade_all_total[(la_grade_all_total['GRADE'] == "80")]
#la_grade4filter

# %%
la_grade_all_withasterisk = la_grade_clean[(la_grade_clean['SUBGROUP'] == "TOTAL")]

# %%
la_grade_all_total = la_grade_all_withasterisk[(la_grade_all_withasterisk['L1 PERCENT'] != "*")]

# %%
len(la_grade_all_total.index)
# Out:
# 11437

# %%
la_grade_all_total['SCHOOL NAME'] =  la_grade_all_total['SCHOOL NAME'].fillna('DISTRICT WIDE')
# Out:
# /Users/castudi1/miniconda2/envs/lovepandas/lib/python2.7/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
la_grade_all_total.head(10)
# Out:
#     COUNTY CODE COUNTY NAME DISTRICT CODE  DISTRICT NAME  SCHOOL CODE  \
# 0            01    ATLANTIC          0010   ABSECON CITY         60.0
# 14           01    ATLANTIC          0010   ABSECON CITY          NaN
# 28           01    ATLANTIC          0110  ATLANTIC CITY         30.0
# 41           01    ATLANTIC          0110  ATLANTIC CITY         50.0
# 54           01    ATLANTIC          0110  ATLANTIC CITY         60.0
# 67           01    ATLANTIC          0110  ATLANTIC CITY         70.0
# 80           01    ATLANTIC          0110  ATLANTIC CITY         80.0
# 92           01    ATLANTIC          0110  ATLANTIC CITY        100.0
# 105          01    ATLANTIC          0110  ATLANTIC CITY        120.0
# 120          01    ATLANTIC          0110  ATLANTIC CITY        140.0
#
#                                  SCHOOL NAME DFG SUBGROUP SUBGROUP_TYPE  \
# 0                             H ASHTON MARSH  CD    TOTAL  ALL STUDENTS
# 14                             DISTRICT WIDE  CD    TOTAL  ALL STUDENTS
# 28                   SOVEREIGN AVENUE SCHOOL   A    TOTAL  ALL STUDENTS
# 41                    CHELSEA HEIGHTS SCHOOL   A    TOTAL  ALL STUDENTS
# 54                       TEXAS AVENUE SCHOOL   A    TOTAL  ALL STUDENTS
# 67                    NEW YORK AVENUE SCHOOL   A    TOTAL  ALL STUDENTS
# 80                     UPTOWN SCHOOL COMPLEX   A    TOTAL  ALL STUDENTS
# 92                   PENNSYLVANIA AVE SCHOOL   A    TOTAL  ALL STUDENTS
# 105                   RICHMOND AVENUE SCHOOL   A    TOTAL  ALL STUDENTS
# 120  DR MARTIN LUTHER KING JR SCHOOL COMPLEX   A    TOTAL  ALL STUDENTS
#
#     REGISTERED TO TEST NOT TESTED ** (See Below) VALID SCORES  \
# 0                   90                        22           68
# 14                  90                        22           68
# 28                   *                         *           72
# 41                   *                         *           37
# 54                   *                         *           74
# 67                   *                         *           58
# 80                   *                         *           63
# 92                   *                         *           48
# 105                  *                         *           55
# 120                  *                         *           77
#
#     MEAN SCALE SCORE L1 PERCENT L2 PERCENT L3 PERCENT L4 PERCENT L5 PERCENT  \
# 0                740       16.2       19.1       20.6       42.6        1.5
# 14               740       16.2       19.1       20.6       42.6        1.5
# 28               722       27.8       27.8         25       18.1        1.4
# 41               746        5.4       18.9         27       45.9        2.7
# 54               710       37.8       36.5       14.9       10.8          0
# 67               714       39.7       25.9       15.5         19          0
# 80               712       33.3       31.7       23.8       11.1          0
# 92               711       43.8       27.1       16.7       10.4        2.1
# 105              733       16.4       18.2         40       23.6        1.8
# 120              707       46.8       24.7       18.2       10.4          0
#
#     GRADE
# 0       3
# 14      3
# 28      3
# 41      3
# 54      3
# 67      3
# 80      3
# 92      3
# 105     3
# 120     3

# %%
la_grade_all_total.to_csv('la_allgrades_total2015.csv', header=True)

# %%
 len(la_grade_all_total.index)
len(math_grade_all_total.index)
# Out:
# 12015

# %%
latest_both_subject = pd.merge(math_grade_all_total, la_grade_all_total, on=['COUNTY CODE', 'DISTRICT CODE', 'SCHOOL CODE', 'COUNTY NAME', 'DISTRICT NAME', 'SCHOOL NAME', 'DFG', 'SUBGROUP', 'SUBGROUP_TYPE', 'GRADE'], how='outer')

# %%
len(latest_both_subject.index)
# Out:
# 12209

# %%
list(latest_both_subject)
# Out:
# [u'COUNTY CODE',
#  u'COUNTY NAME',
#  u'DISTRICT CODE',
#  u'DISTRICT NAME',
#  u'SCHOOL CODE',
#  u'SCHOOL NAME',
#  u'DFG',
#  u'SUBGROUP',
#  u'SUBGROUP_TYPE',
#  u'REGISTERED TO TEST_x',
#  u'NOT TESTED ** (See Below)_x',
#  u'VALID SCORES_x',
#  u'MEAN SCALE SCORE_x',
#  u'L1 PERCENT_x',
#  u'L2 PERCENT_x',
#  u'L3 PERCENT_x',
#  u'L4 PERCENT_x',
#  u'L5 PERCENT_x',
#  'GRADE',
#  u'REGISTERED TO TEST_y',
#  u'NOT TESTED ** (See Below)_y',
#  u'VALID SCORES_y',
#  u'MEAN SCALE SCORE_y',
#  u'L1 PERCENT_y',
#  u'L2 PERCENT_y',
#  u'L3 PERCENT_y',
#  u'L4 PERCENT_y',
#  u'L5 PERCENT_y']

# %%
latest_both_subject.rename(columns={'REGISTERED TO TEST_x': 'PREV_REGISTERED TO TEST_MATH', 'NOT TESTED ** (See Below)_x': 'PREV_NOT TESTED ** (See Below)_MATH', 'VALID SCORES_x': 'PREV_VALID SCORES_MATH', 'MEAN SCALE SCORE_x': 'PREV_MEAN SCALE SCORE_MATH', 'L1 PERCENT_x': 'PREV_L1 PERCENT_MATH', 'L2 PERCENT_x': 'PREV_L2 PERCENT_MATH', 'L3 PERCENT_x': 'PREV_L3 PERCENT_MATH', 'L4 PERCENT_x': 'PREV_L4 PERCENT_MATH', 'L5 PERCENT_x': 'PREV_L5 PERCENT_MATH'}, inplace=True)

# %%
latest_both_subject.rename(columns={'REGISTERED TO TEST_y': 'PREV_REGISTERED TO TEST_LA', 'NOT TESTED ** (See Below)_y': 'PREV_NOT TESTED ** (See Below)_LA', 'VALID SCORES_y': 'PREV_VALID SCORES_LA', 'MEAN SCALE SCORE_y': 'PREV_MEAN SCALE SCORE_LA', 'L1 PERCENT_y': 'PREV_L1 PERCENT_LA', 'L2 PERCENT_y': 'PREV_L2 PERCENT_LA', 'L3 PERCENT_y': 'PREV_L3 PERCENT_LA', 'L4 PERCENT_y': 'PREV_L4 PERCENT_LA', 'L5 PERCENT_y': 'PREV_L5 PERCENT_LA'}, inplace=True)

# %%
list(latest_both_subject)
# Out:
# [u'COUNTY CODE',
#  u'COUNTY NAME',
#  u'DISTRICT CODE',
#  u'DISTRICT NAME',
#  u'SCHOOL CODE',
#  u'SCHOOL NAME',
#  u'DFG',
#  u'SUBGROUP',
#  u'SUBGROUP_TYPE',
#  'PREV_REGISTERED TO TEST_MATH',
#  'PREV_NOT TESTED ** (See Below)_MATH',
#  'PREV_VALID SCORES_MATH',
#  'PREV_MEAN SCALE SCORE_MATH',
#  'PREV_L1 PERCENT_MATH',
#  'PREV_L2 PERCENT_MATH',
#  'PREV_L3 PERCENT_MATH',
#  'PREV_L4 PERCENT_MATH',
#  'PREV_L5 PERCENT_MATH',
#  'GRADE',
#  'PREV_REGISTERED TO TEST_LA',
#  'PREV_NOT TESTED ** (See Below)_LA',
#  'PREV_VALID SCORES_LA',
#  'PREV_MEAN SCALE SCORE_LA',
#  'PREV_L1 PERCENT_LA',
#  'PREV_L2 PERCENT_LA',
#  'PREV_L3 PERCENT_LA',
#  'PREV_L4 PERCENT_LA',
#  'PREV_L5 PERCENT_LA']

# %%
latest_both_subject.to_csv('previous_both_subject.csv', header=True, index=False)
